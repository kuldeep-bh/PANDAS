# %%
import seaborn as sns    #used for advanced visualisation

# %%
import pandas as pd    # used for working with structured data

# %%
import matplotlib.pyplot as plt   # used for normal ploting

# %%
import scipy.stats as st      # used for scientific computing

# %%
# %matplotlib inline      # magic command in jupyter note book to display the plots directly below the code cell

# %%
sns.set_style("whitegrid")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/ASUS/Downloads/heart.csv')      #to read the csv file from computer

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.shape        #gives shape of file i.e how many rows and columns
# Out:
# (1025, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.describe(include='all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].nunique()    #gives the number of unique variable
# Out:
# 2

# %%
df['target'].unique()     #gives type of unique variable or list of values in one column of dataframe
# Out:
# array([0, 1], dtype=int64)

# %%
df['target'].value_counts()    #gives counts of unque values
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
ax= plt.subplots(figsize=(3, 5))
ax = sns.countplot(x="target", data=df)
plt.show()

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="sex",hue="target", data=df)
plt.show()

# %%
ax = sns.catplot(x="target", col="sex", data=df, kind="count", height=5, aspect=1)  #tovisualise relationship b\w two features

# %%
plt.show()

# %%
ax = sns.countplot(y = 'target', hue= 'sex' ,data=df,)

# %%
plt.show()

# %%
ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=df, palette="Set3")
plt.show()

# %%
ax= plt.subplots(figsize=(8, 6))
ax= sns.countplot(x='target',data=df, facecolor = (0, 0, 0, 0), linewidth = 5, edgecolor = sns.color_palette('dark',3))
plt.show()

# %%
ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x='target',data=df,hue='fbs')
plt.show()

# %%
ax = plt.subplots(figsize= (8,6))
ax = sns.countplot(x='target', data=df, hue='exang')
plt.show()

# %% [markdown]
# #bi variate analysis

# %%
correlation = df.corr()

# %%
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
correlation['target'].sort_values(ascending=False)     #help to sort in descending order(highest to lowest)
# Out:
# target      1.000000
# cp          0.434854
# thalach     0.422895
# slope       0.345512
# restecg     0.134468
# fbs        -0.041164
# chol       -0.099966
# trestbps   -0.138772
# age        -0.229324
# sex        -0.279501
# thal       -0.337838
# ca         -0.382085
# exang      -0.438029
# oldpeak    -0.438441
# Name: target, dtype: float64

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp', data=df)
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         375
#     1         122
# 1   1         134
#     0          33
# 2   1         219
#     0          65
# 3   1          51
#     0          26
# Name: count, dtype: int64

# %%
ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp', data=df,hue='target')
plt.show()

# %%
ax = sns.catplot(x='target',data=df,col= 'cp', kind= 'count', height=8, aspect = 1)
plt.show()

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax =sns.distplot(x,bins=10)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
x = pd.Series(x, name= 'thalachvariable')
ax = sns.distplot(x,bins=10)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.distplot(x, bins=10,vertical= True)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
x = pd.Series(x,name= 'thalachvariable')
ax = sns.kdeplot(x)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
x = pd.Series(x, name='thalachvariable')
ax = sns.kdeplot(x,shade = 'True', color='r')   #smooth curve of contineous numerical variable
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
sns.stripplot(x = 'target', y = 'thalach',data= df)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y= 'thalach',data=df,jitter=0.01)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
ax= sns.boxplot(x='target',y='thalach',data=df)
plt.show()

# %% [markdown]
# # heat map for multivariate analysis

# %%
plt.figure(figsize=(16,12))
plt.title('correlation data set of heart disease')
a= sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation= 90)
a.set_yticklabels(a.get_yticklabels(),rotation= 30)
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(df[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %% [markdown]
# # analysis of age and other variable

# %%
df['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].unique()
# Out:
# array([52, 53, 70, 61, 62, 58, 55, 46, 54, 71, 43, 34, 51, 50, 60, 67, 45,
#        63, 42, 44, 56, 57, 59, 64, 65, 41, 66, 38, 49, 48, 29, 37, 47, 68,
#        76, 40, 39, 77, 69, 35, 74], dtype=int64)

# %%
df['age'].describe()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64

# %%
ax= plt.subplots(figsize=(8,6))
x = df['age']
ax = sns.distplot(x,bins=10)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.stripplot(x= 'target',y = 'age', data=df)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.boxplot(x= 'target',y = 'age', data=df)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x= 'age',y = 'trestbps', data=df)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.regplot(x= 'age',y = 'trestbps', data=df)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x= 'age',y = 'chol', data=df)
plt.show()

# %%
ax= plt.subplots(figsize=(8,6))
ax = sns.regplot(x= 'age',y = 'chol', data=df)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x='chol',y='thalach',data=df)
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
ax = sns.regplot(x='chol',y='thalach',data=df)
plt.show()

# %%
# dealing with missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(df).all().all()

# %%
assert (df >= 0).all().all()

# %%
df['age'].describe()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64

# %%
ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    1025.000000
# mean      131.611707
# std        17.516718
# min        94.000000
# 25%       120.000000
# 50%       130.000000
# 75%       140.000000
# max       200.000000
# Name: trestbps, dtype: float64

# %%
ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x = df['trestbps'])
plt.show()
